# %%
import subprocess, sys, time, statistics, pandas as pd
from pathlib import Path

N_REPEATS = 20

# ------------------------------------------------------------------
c_values = [0.005, 0.01, 0.005, 0.001, 0.001, 0.005,  0.005, 0.001]
data= ["Cornell","Dermatology","Glass","HHAR","ISOLET","ORL","USPS","Vehicle"]
# ------------------------------------------------------------------
EPSILONS   = [1.0, 2.0, 4.0, 8.0]
N_REPEATS  = 20
BASE_SEED  = 42                   
OUT_DIR    = Path("exp_results_sklearn"); OUT_DIR.mkdir(exist_ok=True)

# ────────────────────────────────────────────────────────────────────────────
def run_once(ds, dp_method, C, eps, seed):
    multi_class = "crammer_singer" if dp_method == "ours" else "ovr"
    cmd = [
        "python", "main-sklearn.py",
        "--data", ds,
        "--optimizer", "dp_svc",
        "--C", str(C),
        "--eps", str(eps),
        "--dp_method", dp_method,
        "--multi_class", multi_class,
        "--state", str(seed),              
    ]
    proc = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    out, err = proc.communicate()
    if err: print(err, file=sys.stderr)

    acc = None
    for ln in out.splitlines():
        low = ln.lower()
        if "final test accuracy" in low or "test accuracy" in low:
            nums = [s for s in low.replace('%','').split() if s.replace('.','',1).isdigit()]
            if nums:
                acc = float(nums[-1]); break
    if acc is None:
        raise RuntimeError(f"accuracy not found for {ds}-{dp_method}, eps={eps}")
    return acc
# ────────────────────────────────────────────────────────────────────────────

if __name__ == "__main__":
    rows = []
    for ds, C in zip(data,c_values):
        for dp_method in [ "privatesvm", "opera", "ours"]:
            best_C   = None
            best_mu  = -1.0   
            best_std = 0.0

            acc_list = []
            for eps in EPSILONS:
                tmp_acc = []
                for rep in range(N_REPEATS):
                    seed = BASE_SEED + rep
                    acc  = run_once(ds, dp_method, C, eps, seed)
                    tmp_acc.append(acc)
                    time.sleep(0.2)
                mu, sd = statistics.mean(tmp_acc), statistics.stdev(tmp_acc)
                acc_list.append((eps, mu, sd))
                print(f"[{ds:10s} | {dp_method:11s} | C={C:.3g} | ε={eps}] {mu:.3f}±{sd:.3f}")

            overall_mu = statistics.mean([x[1] for x in acc_list])
            if overall_mu > best_mu:
                best_mu, best_std, best_C = overall_mu, sd, C
                best_acc_list = acc_list   

            for eps, mu, sd in best_acc_list:
                rows.append({
                    "dataset": ds,
                    "dp_method": dp_method,
                    "epsilon": eps,
                    "C": best_C,
                    "mean": mu,
                    "std": sd,
                    "latex": f"{mu:.3f}$\\pm${sd:.3f}"
                })

            print(f"▶ [{ds} | {dp_method}] selected C={best_C}")

            pd.DataFrame(rows).to_csv(OUT_DIR/"summary_progress.csv", index=False)
# Out:
# [Cornell    | privatesvm  | C=0.005 | ε=1.0] 0.197±0.089
# [Cornell    | privatesvm  | C=0.005 | ε=2.0] 0.278±0.086
# [Cornell    | privatesvm  | C=0.005 | ε=4.0] 0.448±0.139
# [Cornell    | privatesvm  | C=0.005 | ε=8.0] 0.597±0.201
# ▶ [Cornell | privatesvm] 선택된 C=0.005
# [Cornell    | opera       | C=0.005 | ε=1.0] 0.244±0.095
# [Cornell    | opera       | C=0.005 | ε=2.0] 0.333±0.127
# [Cornell    | opera       | C=0.005 | ε=4.0] 0.505±0.172
# [Cornell    | opera       | C=0.005 | ε=8.0] 0.683±0.222
# ▶ [Cornell | opera] 선택된 C=0.005
# [Cornell    | ours        | C=0.005 | ε=1.0] 0.404±0.138
# [Cornell    | ours        | C=0.005 | ε=2.0] 0.596±0.182
# [Cornell    | ours        | C=0.005 | ε=4.0] 0.707±0.228
# [Cornell    | ours        | C=0.005 | ε=8.0] 0.762±0.252
# ▶ [Cornell | ours] 선택된 C=0.005
# [Dermatology | privatesvm  | C=0.01 | ε=1.0] 0.240±0.120
# [Dermatology | privatesvm  | C=0.01 | ε=2.0] 0.422±0.142
# [Dermatology | privatesvm  | C=0.01 | ε=4.0] 0.595±0.146
# [Dermatology | privatesvm  | C=0.01 | ε=8.0] 0.858±0.078
# ▶ [Dermatology | privatesvm] 선택된 C=0.01
# [Dermatology | opera       | C=0.01 | ε=1.0] 0.296±0.131
# [Dermatology | opera       | C=0.01 | ε=2.0] 0.465±0.141
# [Dermatology | opera       | C=0.01 | ε=4.0] 0.698±0.134
# [Dermatology | opera       | C=0.01 | ε=8.0] 0.897±0.058
# ▶ [Dermatology | opera] 선택된 C=0.01
# [Dermatology | ours        | C=0.01 | ε=1.0] 0.455±0.165
# [Dermatology | ours        | C=0.01 | ε=2.0] 0.718±0.103
# [Dermatology | ours        | C=0.01 | ε=4.0] 0.851±0.080
# [Dermatology | ours        | C=0.01 | ε=8.0] 0.857±0.062
# ▶ [Dermatology | ours] 선택된 C=0.01
# [Glass      | privatesvm  | C=0.005 | ε=1.0] 0.201±0.127
# [Glass      | privatesvm  | C=0.005 | ε=2.0] 0.273±0.103
# [Glass      | privatesvm  | C=0.005 | ε=4.0] 0.363±0.124
# [Glass      | privatesvm  | C=0.005 | ε=8.0] 0.371±0.077
# ▶ [Glass | privatesvm] 선택된 C=0.005
# [Glass      | opera       | C=0.005 | ε=1.0] 0.281±0.129
# [Glass      | opera       | C=0.005 | ε=2.0] 0.395±0.104
# [Glass      | opera       | C=0.005 | ε=4.0] 0.378±0.108
# [Glass      | opera       | C=0.005 | ε=8.0] 0.377±0.083
# ▶ [Glass | opera] 선택된 C=0.005
# [Glass      | ours        | C=0.005 | ε=1.0] 0.180±0.127
# [Glass      | ours        | C=0.005 | ε=2.0] 0.195±0.119
# [Glass      | ours        | C=0.005 | ε=4.0] 0.186±0.127
# [Glass      | ours        | C=0.005 | ε=8.0] 0.230±0.156
# ▶ [Glass | ours] 선택된 C=0.005
# [HHAR       | privatesvm  | C=0.001 | ε=1.0] 0.575±0.137
# [HHAR       | privatesvm  | C=0.001 | ε=2.0] 0.789±0.101
# [HHAR       | privatesvm  | C=0.001 | ε=4.0] 0.889±0.023
# [HHAR       | privatesvm  | C=0.001 | ε=8.0] 0.912±0.009
# ▶ [HHAR | privatesvm] 선택된 C=0.001
# [HHAR       | opera       | C=0.001 | ε=1.0] 0.674±0.105
# [HHAR       | opera       | C=0.001 | ε=2.0] 0.864±0.040
# [HHAR       | opera       | C=0.001 | ε=4.0] 0.898±0.016
# [HHAR       | opera       | C=0.001 | ε=8.0] 0.913±0.005
# ▶ [HHAR | opera] 선택된 C=0.001
# [HHAR       | ours        | C=0.001 | ε=1.0] 0.878±0.022
# [HHAR       | ours        | C=0.001 | ε=2.0] 0.890±0.018
# [HHAR       | ours        | C=0.001 | ε=4.0] 0.895±0.007
# [HHAR       | ours        | C=0.001 | ε=8.0] 0.897±0.007
# ▶ [HHAR | ours] 선택된 C=0.001
# [ISOLET     | privatesvm  | C=0.001 | ε=1.0] 0.053±0.021
# [ISOLET     | privatesvm  | C=0.001 | ε=2.0] 0.054±0.017
# [ISOLET     | privatesvm  | C=0.001 | ε=4.0] 0.072±0.032
# [ISOLET     | privatesvm  | C=0.001 | ε=8.0] 0.137±0.048
# ▶ [ISOLET | privatesvm] 선택된 C=0.001
# [ISOLET     | opera       | C=0.001 | ε=1.0] 0.046±0.020
# [ISOLET     | opera       | C=0.001 | ε=2.0] 0.063±0.023
# [ISOLET     | opera       | C=0.001 | ε=4.0] 0.123±0.044
# [ISOLET     | opera       | C=0.001 | ε=8.0] 0.205±0.055
# ▶ [ISOLET | opera] 선택된 C=0.001
# [ISOLET     | ours        | C=0.001 | ε=1.0] 0.147±0.051
# [ISOLET     | ours        | C=0.001 | ε=2.0] 0.295±0.081
# [ISOLET     | ours        | C=0.001 | ε=4.0] 0.513±0.048
# [ISOLET     | ours        | C=0.001 | ε=8.0] 0.675±0.057
# ▶ [ISOLET | ours] 선택된 C=0.001
# [ORL        | privatesvm  | C=0.005 | ε=1.0] 0.021±0.016
# [ORL        | privatesvm  | C=0.005 | ε=2.0] 0.027±0.017
# [ORL        | privatesvm  | C=0.005 | ε=4.0] 0.021±0.016
# [ORL        | privatesvm  | C=0.005 | ε=8.0] 0.022±0.019
# ▶ [ORL | privatesvm] 선택된 C=0.005
# [ORL        | opera       | C=0.005 | ε=1.0] 0.026±0.015
# [ORL        | opera       | C=0.005 | ε=2.0] 0.028±0.019
# [ORL        | opera       | C=0.005 | ε=4.0] 0.028±0.017
# [ORL        | opera       | C=0.005 | ε=8.0] 0.033±0.026
# ▶ [ORL | opera] 선택된 C=0.005
# [ORL        | ours        | C=0.005 | ε=1.0] 0.036±0.015
# [ORL        | ours        | C=0.005 | ε=2.0] 0.047±0.023
# [ORL        | ours        | C=0.005 | ε=4.0] 0.069±0.034
# [ORL        | ours        | C=0.005 | ε=8.0] 0.141±0.054
# ▶ [ORL | ours] 선택된 C=0.005
# [USPS       | privatesvm  | C=0.005 | ε=1.0] 0.184±0.071
# [USPS       | privatesvm  | C=0.005 | ε=2.0] 0.257±0.093
# [USPS       | privatesvm  | C=0.005 | ε=4.0] 0.503±0.121
# [USPS       | privatesvm  | C=0.005 | ε=8.0] 0.769±0.069
# ▶ [USPS | privatesvm] 선택된 C=0.005
# [USPS       | opera       | C=0.005 | ε=1.0] 0.236±0.068
# [USPS       | opera       | C=0.005 | ε=2.0] 0.367±0.105
# [USPS       | opera       | C=0.005 | ε=4.0] 0.642±0.088
# [USPS       | opera       | C=0.005 | ε=8.0] 0.843±0.026
# ▶ [USPS | opera] 선택된 C=0.005
# [USPS       | ours        | C=0.005 | ε=1.0] 0.710±0.095
# [USPS       | ours        | C=0.005 | ε=2.0] 0.884±0.020
# [USPS       | ours        | C=0.005 | ε=4.0] 0.918±0.009
# [USPS       | ours        | C=0.005 | ε=8.0] 0.926±0.007
# ▶ [USPS | ours] 선택된 C=0.005
# [Vehicle    | privatesvm  | C=0.001 | ε=1.0] 0.312±0.058
# [Vehicle    | privatesvm  | C=0.001 | ε=2.0] 0.356±0.073
# [Vehicle    | privatesvm  | C=0.001 | ε=4.0] 0.377±0.064
# [Vehicle    | privatesvm  | C=0.001 | ε=8.0] 0.386±0.057
# ▶ [Vehicle | privatesvm] 선택된 C=0.001
# [Vehicle    | opera       | C=0.001 | ε=1.0] 0.331±0.053
# [Vehicle    | opera       | C=0.001 | ε=2.0] 0.345±0.053
# [Vehicle    | opera       | C=0.001 | ε=4.0] 0.384±0.068
# [Vehicle    | opera       | C=0.001 | ε=8.0] 0.379±0.047
# ▶ [Vehicle | opera] 선택된 C=0.001
# [Vehicle    | ours        | C=0.001 | ε=1.0] 0.266±0.055
# [Vehicle    | ours        | C=0.001 | ε=2.0] 0.311±0.055
# [Vehicle    | ours        | C=0.001 | ε=4.0] 0.297±0.054
# [Vehicle    | ours        | C=0.001 | ε=8.0] 0.383±0.097
# ▶ [Vehicle | ours] 선택된 C=0.001
